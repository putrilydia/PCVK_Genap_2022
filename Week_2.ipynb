# %%
from google.colab import drive
# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten02.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# Menggunakan figsize untuk mengubah ukuran

# %%
plt.figure(figsize=(3,3))
plt.imshow(img3)

# %% [markdown]
# 1. Tampilkan image dalam channel Red-Green dan Green-Blue saja!

# %%
img4 = img3
#Red - Green
img4[:,:,0] = np.zeros([img4.shape[0], img4.shape[1]])
plt.imshow(img4)

# %%
#Blue - Green
img5 = img3

img5[:,:,2] = np.zeros([img5.shape[0], img5.shape[1]])
plt.imshow(img5)

# %% [markdown]
# 2. Tampilkan image baris ke 10-100, kolom 10-100!

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3[10:100, 10:100])

# %% [markdown]
# 3. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!

# %%
plt.imshow(img5[5:30])

# %% [markdown]
# 4.Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!

# %%
import random

img6 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
for x in range(5):
  startp = random.randint(0,350)
  endp = random.randint(0,350)

  c1 = random.randint(0,255)
  c2 = random.randint(0,255)
  c3 = random.randint(0,255)
  start_point = (startp , startp) 
    
  end_point = (endp, endp) 
    
  color = (c1, c2, c3) 
    
  thickness = 7
    
  img6 = cv.rectangle(img3, start_point, end_point, color, thickness) 
    
# Displaying the image  
plt.imshow(img6)

# %% [markdown]
# 5. Tampilkan image dengan posisi terbalik!

# %%
img7 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
plt.imshow(img7)

# %% [markdown]
# Menampilkan citra Grayscale, melakukan resizing, melakukan Flipping, Menyimpan citra hasil

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten02.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna
# ‘gray’

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna 'magma'

# %%
plt.imshow(img_gray, cmap='magma')

# %% [markdown]
# Citra RGB di resize dalam ukuran panjang 512 dan lebar 1024

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %% [markdown]
# Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
#simpan file image
#cv.imwrite('/content/drive/MyDrive/PCVK/Images/Mount.jpg', img5)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# Membuat bentuk Geometri 2D dari OpenCV. Diawal dengan pembuatan black image dengan tipe data int16.

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,250,0),thickness=10)
plt.imshow(black_img)

# %% [markdown]
# Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2 yang tertulis pada kode program.

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %% [markdown]
# Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang tertulis pada kode program.

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %% [markdown]
# Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut.

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %% [markdown]
# Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut.

# %%
cv.circle(black_img, center=(400,400), radius=50, color=(255,0,0), thickness=-2)
plt.imshow(black_img)

# %% [markdown]
# Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah ditentukan.

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# Pembuatan black image kembali dilakukan dengan tipe data int3

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# Berikut adalah kode program untuk inisialisasi NumPy array dengan tipe data int32

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# Array tersebut kemudian di reshape sebagai berikut

# %%
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R,G,B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# Penambahan polyline pada black image kedua yang telah dibuat.

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# Setelah semua kode selesai simpan “Week2.ipynb” pada GiHub Anda dengan memilih File kemudian “Save a copy in GitHub”.

# %% [markdown]
# TUGAS Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :

# %% [markdown]
# 6. Buat rectangle dan circle pada bagian wajah dari image kitten!

# %%
img_sc7 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img_sc7,pt1=(100,450),pt2=(550,50),color=(255,255,255),thickness=3)
cv.circle(img_sc7,center=(350,250),radius=200,color=(255,0,0),thickness=3)
plt.imshow(img_sc7)

# %% [markdown]
# 7. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten01.jpg!

# %%
img_sc8 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img_sc8,pt1=(0,400),pt2=(100,500),color=(0,0,255),thickness=3)
plt.imshow(img_sc8)

# %% [markdown]
# Pertanyaan
#
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
# 3. Jelaskan tentang angka-angka yang terdapat pada reshape((-1,1,2))
# 4. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode berikut
# 5.. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3

# %% [markdown]
# 1. Gambar yang ditampilkan dengan matplotlib dapat merepresentasikan data menjadi warna dan glyphs seperti marker (lingkaran), line(garis) dan poligon. Sementara gambar yang ditampilkan tanpa matplotlib tidak dapat merepresentasikan data seperti gambar yang ditampilkan dengan menggunakan matplotlib.
# 2.perbedaan pada ukuran gambar, tergantung dari int. semakin kecil tipe data int yang diberikan maka semakin sedikit juga kapasitasnya dan semakin besar tipe data int yang diberikan maka semakin besar juga kapasitasnya. Cuma berbeda kapasitas saja dari int16 dan int32
# 3. reshape digunakan untuk mengubah bentuk bangun
# 4.Kode di baris atas menambahkan satu patches karena cv.imshow tidak berjalan di Google Colab maupun Jupyter Notebook. Variabel img merupakan citra asli, sementara grayImg yang sudah dikonversi ke hitam putih (gray)
# 5.untuk men-load gambar, read dan write gambar
